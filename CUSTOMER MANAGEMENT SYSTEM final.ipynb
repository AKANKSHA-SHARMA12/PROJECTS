# %%
    #BLL
list_ID=[]
list_Name=[]
list_Address=[]
list_M=[]

def add(Id,Name,Address,M_No):
    list_ID.append(Id)
    list_Name.append(Name)
    list_Address.append(Address)
    list_M.append(M_No)
    return True

def validate(Id):
    
    if list_ID.__contains__(Id):
        return True
    return False
        
def search(Id):
    if list_ID.__contains__(Id): 
        i=list_ID.index(Id)
        Name=list_Name[i]
        Address=list_Address[i]
        Mobile=list_M[i]
        str_data="\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
        return str_data
    else:
        return "Id not found"

def delete(Id):
    if list_ID.__contains__(Id): 
        i=list_ID.index(Id)
        list_Name.pop(i)
        list_Address.pop(i)
        list_M.pop(i)
        list_ID.pop(i)
        str_data="Customer deleted successfully"
        return str_data
    else:
        return "Customer not found"

def Update(Id,Name,Address,M_No):
    if list_ID.__contains__(Id): 
        i=list_ID.index(Id)
        list_Name[i]=Name
        list_Address[i]=Address
        list_M[i]=M_No
        str_data="Customer details updated successfully"
        return str_data
    else:
        return "Customer not found"

def Show_all():
    str_data=""
    for i in range(len(list_ID)):
        str_data+="Id:"+str(list_ID[i])+"\t"+"Name:"+list_Name[i]+"\t"+"Address:"+list_Address[i]+"\t"+"Mobile Number:"+list_M[i]+"\n"
    return str_data  


#3
    
def Search_key(key):
    str_data=""
    if list_ID.__contains__(key): 
        i=list_ID.index(key)
        Id=list_ID[i]
        Name=list_Name[i]
        Address=list_Address[i]
        Mobile=list_M[i]
        str_data="Id:"+str(Id)+"\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
    elif list_Name.__contains__(key):
        i=list_Name.index(key)
        Id=list_ID[i]
        Name=list_Name[i]
        Address=list_Address[i]
        Mobile=list_M[i]
        str_data="Id:"+str(Id)+"\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
    elif list_Address.__contains__(key):
        i=list_Address.index(key)
        Id=list_ID[i]
        Name=list_Name[i]
        Address=list_Address[i]
        Mobile=list_M[i]
        str_data="Id:"+str(Id)+"\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
        
    elif list_M.__contains__(key):
        i=list_M.index(key)
        Id=list_ID[i]
        Name=list_Name[i]
        Address=list_Address[i]
        Mobile=list_M[i]
        str_data="Id:"+str(Id)+"\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
    else:
        str_data="Entered data not found"
        
    
    #Id=list_ID[i]
    #Name=list_Name[i]
    #Address=list_Address[i]
    #Mobile=list_M[i]
    
    #str_data="Id:"+str(Id)+"\n Name:"+Name+"\n Address:"+Address+"\n mobile:"+Mobile
    return str_data

def Update_by(old,new):
    str_data=""
    if list_ID.__contains__(old): 
        i=list_ID.index(old)
        list_ID[i]=new
    elif list_Name.__contains__(old):
        i=list_Name.index(old)
        list_Name[i]=new
    elif list_Address.__contains__(old):
        i=list_Address.index(old)
        list_Address[i]=new
    elif list_M.__contains__(old):
        i=list_M.index(old)
        list_M[i]=new
    else:
        str_data="Entered data not found"
      
    str_data="Customer details updated successfully"
    
    return str_data
    
    
    
#PRESENTATION LAYER
while(True):
   
    print("\n1.ADD Customer\n2.Search Customer\n3.Delete Customer\n4.Modify Customer\n5.Show all customer\n6.Search customer by any key:\n7.Update using option\n8.Exit")
    
    ch=input("Enter your choice")
    if ch=='1':
    #Write code to add customer
        Id=int(input("Enter customer ID"))
        Name=input("Enter Name:")
        Address=input("Enter Address")
        M_No=input("Enter Mobile Number:")
        result=add(Id,Name,Address,M_No)
        if result==True:
            print("\nCustomer Information added successfully\n")
        else:
            print("Something wrong")
        
        pass
    elif ch=='2':
    #Write code to Search customer 
        Id=int(input("Enter customer ID"))
        
        Str=search(Id)
        print(Str)
            #print("Customer Id is:",Id,"\n",'Name:',q,"\n","Address:",r,"\n",'Mobile:',s)
        #else:
            #print("Customer Information not found")
        pass
    elif ch=='3':
    #Write code to Delete customer
        Id=int(input("Enter customer ID you want to delete:"))
        Str=delete(Id)
        print(Str)
        
        pass
    elif ch=='4':
    #Write code to Modify customer
        Id=int(input("Enter customer ID"))
        Name=input("Enter Name:")
        Address=input("Enter Address")
        M_No=input("Enter Mobile Number:")
        Str=Update(Id,Name,Address,M_No)
        print(Str)
        pass
    elif ch=='5':
     #Write code to Show all customer
        Str=Show_all()
        print(Str)
        pass
    
  
    elif ch=='6':
    #Write to search by any key
        key=input("Any the key to search:")
        Str=Search_key(key)
        print(Str)
        pass
    elif ch=='7':
        #Write program to update a particular field
        print("Enter the field to update:\n1.Id\n2.Name\n3.Address\n4.Mobile")
        choice=input("Enter your choice:")
        if choice=='1':
            old=int(input("\nEnter old Id:"))
            new=int(input("\nEnter new Id:"))
            Str=Update_by(old,new)
            print(Str)
        elif choice=='2':
            old=input("Enter old name:")
            new=input("Enter new name:")
            Str=Update_by(old,new)
            print(Str)
        elif choice=='3':
            old=input("Enter old Address:")
            new=input("Enter new Address:")
            Str=Update_by(old,new)
            print(Str)
        elif choice=='4':
            old=input("Enter old Mobile no.")
            new=input("Enter new Mobile no.")
            Str=Update_by(old,new)
            print(Str)
        else:
            print("Not a valid entry")
            
        
        
        pass
    elif ch=='8':
            print("Thank you")   
            pass  
    else:
           
        
        
        break
# Out:
# 1.ADD Customer
# 2.Search Customer
# 3.Delete Customer
# 4.Modify Customer
# 5.Show all customer
# 6.Search customer by any key:
# 7.Update using option
# 8.Exit
# Enter your choice1
# Enter customer ID1
# Enter Name:a
# Enter Addressaa
# Enter Mobile Number:aaa
#
# Customer Information added successfully
#
#
# 1.ADD Customer
# 2.Search Customer
# 3.Delete Customer
# 4.Modify Customer
# 5.Show all customer
# 6.Search customer by any key:
# 7.Update using option
# 8.Exit
# Enter your choice7
# Enter the field to update:
# 1.Id
# 2.Name
# 3.Address
# 4.Mobile
# Enter your choice:hi
# Not a valid entry
#
# 1.ADD Customer
# 2.Search Customer
# 3.Delete Customer
# 4.Modify Customer
# 5.Show all customer
# 6.Search customer by any key:
# 7.Update using option
# 8.Exit
# Enter your choice7
# Enter the field to update:
# 1.Id
# 2.Name
# 3.Address
# 4.Mobile
# Enter your choice:2
# Enter old name:aa
# Enter new name:aaa
# Customer details updated successfully
#
# 1.ADD Customer
# ...

# %%
print("""\n1.ADD Customer\n2.Search Customer\n3.Delete Customer\n4.Modify Customer\n5.Show all customer\
\n6.Search customer by any key\n7.Update using option\n8.Exit""")
# Out:
# 1.ADD Customer
# 2.Search Customer
# 3.Delete Customer
# 4.Modify Customer
# 5.Show all customer
# 6.Search customer by any key
# 7.Update using option
# 8.Exit
#
# 1.ADD Customer
# 2.Search Customer
# 3.Delete Customer
# 4.Modify Customer
# 5.Show all customer
# 6.Search customer by any key
# 7.Update using option
# 8.Exit
